# %%
from __future__ import division
from numpy.fft import *

close('all')

# %%
M=100

t=linspace(0,10,M)

f1>=(33 - t)/3
f2<=(36-3*t)/2
f3<=(8-0.5*t)/0.25
f4<=(4-0.2*t)/0.2
f5<=(72-t)/5
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,  True], dtype=bool)

# %%
figure(1,[20.5,20.5])
subplot(2,2,1),plot(t,f1,'o'),grid(True)
subplot(2,2,1),plot(t,f2),grid(True)
subplot(2,2,1),plot(t,f3),grid(True)
subplot(2,2,1),plot(t,f4),grid(True)
subplot(2,2,1),plot(t,f5),grid(True)
# Out:
# (<matplotlib.axes.AxesSubplot at 0x7f39c050bd10>,
#  [<matplotlib.lines.Line2D at 0x7f39c053f0d0>],
#  None)

# %%
from sympy.plotting import plot_implicit
p = plot_implicit(y < x*x) # also creates a window with the plot
the_matplotlib_axes_instance = p._backend._ax
p = plot_implicit(y < x**2) # also creates a window with the plot
the_matplotlib_axes_instance = p._backend._ax
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-b00b55c163f0> in <module>()
#       1 from sympy.plotting import plot_implicit
#       2 p = plot_implicit(y < x*x) # also creates a window with the plot
# ----> 3 the_matplotlib_axes_instance = p._backend._ax
#       4 p = plot_implicit(y < x**2) # also creates a window with the plot
#       5 the_matplotlib_axes_instance = p._backend._ax
#
# AttributeError: 'MatplotlibBackend' object has no attribute '_ax'

# %%
from sympy import plot_implicit, cos, sin, symbols, Eq, And
x1, x2 = symbols('x1 x2')

# %%
figure(1,[20.5,20.5])
subplot(2,2,1), plot_implicit(3*x1 + 2*x2 <= 36, (x1, -20, 20), (x2, -20, 20)  )
# Out:
# (<matplotlib.axes.AxesSubplot at 0x7f39c018b150>,
#  <sympy.plotting.plot.Plot at 0x7f39bbb5f4d0>)

# %%
p2 = plot_implicit(0.5*x1 + 0.25*x2 <= 8)
p3 = plot_implicit(0.2*x1 + 0.2*x2 <= 4)
p4 = plot_implicit(x1 + 5*x2 <= 72)
p5 = plot_implicit(x1 + 3*x2 >= 33)
